# %%
# Brasília Scatter Plots - Explanatory Variables

# %%
# read the data into a pandas DataFrame
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="white") #white background style for seaborn plots
sns.set(style="whitegrid", color_codes=True)

# %%
df = pd.read_excel(r"Brasilia_ML.xls")
df.head()
# Out:
#    Weekbegin       SPD  Price_sd        CV  Price_skewness  Price_kurtosis  \
# 0 2009-11-22  0.018148  0.012578  0.004609       -0.922580        3.556941
# 1 2009-11-29  0.010662  0.005758  0.002108        1.310996        5.542839
# 2 2009-12-13  0.030578  0.014509  0.005324       -4.220843       21.403550
# 3 2009-12-20  0.014444  0.007467  0.002737       -2.711347       10.610342
# 4 2009-12-27  0.018216  0.011757  0.004315       -1.759335        5.388239
#
#    Cartel_DF
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
# scatter plots  
# explanatory variables (SPD, Price_sd, CV, Price_skewness and Price_Kurtosis) over time (Weekbegin)
plt.scatter(df.Weekbegin, df.SPD, marker='o',color='blue', s=5)
plt.axvline(x=16780, color="red", label="CADE's preventive measure")
plt.legend(loc='best', prop={'size':8})
plt.title('Brasília')
plt.xlabel('Date')
plt.ylabel('Spread')
plt.grid(False)
plt.savefig('Scatter_SPD_Brasilia.png', dpi=600)
plt.savefig('Scatter_SPD_Brasilia.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.scatter(df.Weekbegin, df.Price_sd,marker='o',color='blue', s=5)
plt.axvline(x=16780, color="red", label="CADE's preventive measure")
plt.legend(loc='best', prop={'size':8})
plt.title('Brasília')
plt.xlabel('Date')
plt.ylabel('Standard Deviation')
plt.grid(False)
plt.savefig('Scatter_Std_Brasilia.png', dpi=600)
plt.savefig('Scatter_Std_Brasilia.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.scatter(df.Weekbegin, df.CV, marker='o',color='blue', s=5)
plt.axvline(x=16780, color="red", label="CADE's preventive measure")
plt.legend(loc='best', prop={'size':8})
plt.title('Brasília')
plt.xlabel('Date')
plt.ylabel('Coefficient of Variation')
plt.grid(False)
plt.savefig('Scatter_CV_Brasilia.png', dpi=600)
plt.savefig('Scatter_CV_Brasilia.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.scatter(df.Weekbegin, df.Price_skewness, marker='o',color='blue', s=5)
plt.axvline(x=16780, color="red", label="CADE's preventive measure")
plt.legend(loc='best', prop={'size':8})
plt.title('Brasília')
plt.xlabel('Date')
plt.ylabel('Skewness')
plt.grid(False)
plt.savefig('Scatter_Skew_Brasilia.png', dpi=600)
plt.show()

# %%
plt.scatter(df.Weekbegin, df.Price_kurtosis, marker='o',color='blue', s=5)
plt.axvline(x=16780, color="red", label="CADE's preventive measure")
plt.legend(loc='best', prop={'size':8})
plt.title('Brasília')
plt.xlabel('Date')
plt.ylabel('Kurtosis')
plt.grid(False)
plt.savefig('Scatter_Kurt_Brasilia.png', dpi=600)
plt.savefig('Scatter_Kurt_Brasilia.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
