# %% [markdown]
# <a href="https://colab.research.google.com/github/estevaocardoso/projetos-estevao/blob/GAS_ML/WORKING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import basedosdados as bd

# %%
query = '''
SELECT ano, sigla_uf, id_municipio, bairro_revenda, cep_revenda, endereco_revenda, cnpj_revenda, nome_estabelecimento, bandeira_revenda, produto, unidade_medida, preco_compra, preco_venda FROM `basedosdados.br_anp_precos_combustiveis.microdados`
WHERE sigla_uf = 'PA'
'''
df = bd.read_sql(query,
billing_project_id="extended-spark-302513")
# Out:
# Downloading: 100%|██████████| 299122/299122 [00:28<00:00, 10422.27rows/s]

# %% [markdown]
# # Nova seção

# %%
df
# Out:
#          ano sigla_uf id_municipio bairro_revenda cep_revenda  \
# 0       2005       PA      1502707                   00000000
# 1       2005       PA      1502707                   00000000
# 2       2005       PA      1502707                   00000000
# 3       2005       PA      1502707                   00000000
# 4       2005       PA      1504208                   00000000
# ...      ...      ...          ...            ...         ...
# 299117  2023       PA      1500602      Aparecida    68371441
# 299118  2023       PA      1500602      Aparecida    68371441
# 299119  2023       PA      1500602      Aparecida    68371441
# 299120  2023       PA      1500602      Aparecida    68371441
# 299121  2023       PA      1506807         Cipoal    68033010
#
#                                          endereco_revenda     cnpj_revenda  \
# 0                  Rua Dom Domingos Carrerot, 2020, S/N,    04214052000383
# 1                  Rua Dom Domingos Carrerot, 2020, S/N,    04214052000383
# 2                  Rua Dom Domingos Carrerot, 2020, S/N,    04214052000383
# 3                  Rua Dom Domingos Carrerot, 2020, S/N,    04214052000383
# 4                        Av. Transamazonica , 1961, S/N,    05011176000596
# ...                                                   ...              ...
# 299117  Rodovia Ernesto Acyoli, S/N, Lote  2 A 14     ...   19302875000176
# 299118  Rodovia Ernesto Acyoli, S/N, Lote  2 A 14     ...   19302875000176
# 299119  Rodovia Ernesto Acyoli, S/N, Lote  2 A 14     ...   19302875000176
# 299120  Rodovia Ernesto Acyoli, S/N, Lote  2 A 14     ...   19302875000176
# 299121  Rodovia Santarem-Cuiaba, Km 16, Lote  03      ...   25079318000130
#
#                          nome_estabelecimento bandeira_revenda  \
# 0                         Souza & Vieira Ltda           Branca
# 1                         Souza & Vieira Ltda           Branca
# 2                         Souza & Vieira Ltda           Branca
# 3                         Souza & Vieira Ltda           Branca
# 4       Madegas Comercio E Representacao Ltda           Branca
# ...                                       ...              ...
# 299117                     Posto Bonanza Ltda         Ipiranga
# 299118                     Posto Bonanza Ltda         Ipiranga
# 299119                     Posto Bonanza Ltda         Ipiranga
# 299120                     Posto Bonanza Ltda         Ipiranga
# 299121                   Auto Posto Davi Ltda         Ipiranga
#
#                    produto unidade_medida  preco_compra  preco_venda
# 0                      Glp        R$/13kg           NaN        33.00
# 1                      Glp        R$/13kg           NaN        33.00
# 2                      Glp        R$/13kg           NaN        33.00
# 3                      Glp        R$/13kg           NaN        33.00
# 4                      Glp        R$/13kg           NaN        33.00
# ...                    ...            ...           ...          ...
# 299117  Gasolina Aditivada       R$/litro           NaN         6.75
# 299118  Gasolina Aditivada       R$/litro           NaN         5.85
# 299119  Gasolina Aditivada       R$/litro           NaN         6.10
# 299120  Gasolina Aditivada       R$/litro           NaN         6.61
# 299121  Gasolina Aditivada       R$/litro           NaN         5.20
#
# [299122 rows x 13 columns]
