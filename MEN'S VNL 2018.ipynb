# %%
import json
from bs4 import BeautifulSoup

# %% [markdown]
# VNL 2018 MEN'S - PLAYER STATISTICS

# %%
import requests


url = "https://en.volleyballworld.com/en/vnl/2018/men/statistics"

payload = {}
headers = {
  'authority': 'en.volleyballworld.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': '_gcl_au=1.1.1087252023.1696070766; _tt_enable_cookie=1; _ttp=mC9cwvZDEfFvm84XhcY_UpCFQS1; __qca=P0-22326168-1696070767255; _hjSessionUser_3054680=eyJpZCI6Ijc5NjFiZWRhLWFiYmItNTFmMi05YjZlLTljMWE4Mjg0Yzk2MiIsImNyZWF0ZWQiOjE2OTYwNzA3ODA1MjcsImV4aXN0aW5nIjp0cnVlfQ==; _vwo_uuid_v2=DB3B3C099E1E6AF8DAD0304C6CC4A4098|a687021c2fb118a0e3b8b34c2e8eef96; _hjSessionUser_1859763=eyJpZCI6IjcwNmIzOWRmLWU2ZWQtNWIyNC04YzgxLWQxYjczMmQxMWU2NCIsImNyZWF0ZWQiOjE2OTYwNzA3NjYxMjIsImV4aXN0aW5nIjp0cnVlfQ==; _ga=GA1.1.173820319.1696070762; _gid=GA1.2.283440947.1696070762; OptanonAlertBoxClosed=2023-09-30T22:00:03.458Z; _hjSession_1859763=eyJpZCI6IjgxNzI0ZGE4LTE3NzAtNDE3OC05NzkyLTA1ZDkzYTIyZmY4NyIsImNyZWF0ZWQiOjE2OTczNzIwMzk0NDEsImluU2FtcGxlIjpmYWxzZSwic2Vzc2lvbml6ZXJCZXRhRW5hYmxlZCI6dHJ1ZX0=; _hjAbsoluteSessionInProgress=0; _gid=GA1.2.283440947.1696070762; azureb2c_ver=1.0; azureb2c_iss=https%3A%2F%2Faccount.volleyballworld.com%2Ffa39777d-dc84-467d-9c08-a3ba7777d7bd%2Fv2.0%2F; azureb2c_sub=f093a8ae-9611-4ac4-bf61-45d340583b79; azureb2c_aud=9d086c90-823a-47bb-a3c0-9711adc6ddee; azureb2c_exp=1697375655; azureb2c_nonce=defaultNonce%2CdefaultNonce; azureb2c_iat=1697372055; azureb2c_auth_time=1697372055; azureb2c_given_name=Estevao; azureb2c_family_name=Cardoso; azureb2c_idp=google.com; azureb2c_idp_access_token=ya29.a0AfB_byCwSn_o56JoGgINN0ftonTOZiLBjvQB8BJDNRvgrDrRbgmFwYn-HV2qanTaA7l0X5h6AbFzB-nkyUHg3VjIXAfyWLYsP8CBHSw1oFCm8MFRTFnQ-2Qlp2_cPmjb-6ROCsHooKTJ2UcfsL4bObHOhYPCwxRKFuxaaCgYKAVcSARESFQGOcNnCRe4Ah75WoHAhVZdPdd6GYg0171; azureb2c_oid=f093a8ae-9611-4ac
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# COLETANDO OS HEADERS DAS TABELA

# %%
ht = soup.find_all("th")

# %%
headers_total = [i.text for i in ht if i.text]
headers_total

# %% [markdown]
# COLETANDO OS DADOS TABELA POR TABELA

# %%
tabelas = soup.find_all("div", class_="fivb-tabnav__container")

# %%
scorers = soup.find('div', {'id': 'scorers'})
spikers = soup.find('div', {'id': 'spikers'})
blockers = soup.find('div', {'id': 'blockers'})
servers = soup.find('div', {'id': 'servers'})
setters = soup.find('div', {'id': 'setters'})
diggers = soup.find('div', {'id': 'diggers'})
receivers = soup.find('div', {'id': 'receivers'})

# %% [markdown]
# CONSTRUINDO AS TABELAS

# %%
trsc = scorers.find_all('tr')
#scorers_header = [th.text for th in scorers.find_all('th')]
scorers_body = [td.text for td in trsc.find_all('td')]
scorers_body

# %%
scorers_header = [th.text for th in scorers.find_all('th')]
scorers_header

# %%
all_data_scr = []
rows_scr = scorers.find_all('tr')
scorers_rows = []

for row in rows_scr[1:]:
    row_data = row.find_all('td')
    row_values = [data.text for data in row_data]
    scorers_rows.append(row_values)
    data = dict(zip(scorers_header,row_values))
    print(data)
    all_data_scr.append(data)

for row in scorers_rows:
    print(row)
# Out:
# {'Rank': '1', 'ShirtNumber': '8', 'Name': 'Wallace De Souza', 'Team': 'BRA', 'Attacks': '240', 'Blocks': '21', 'Serves': '16', 'Total': '277'}
# {'Rank': '2', 'ShirtNumber': '2', 'Name': 'Chuan Jiang', 'Team': 'CHN', 'Attacks': '242', 'Blocks': '19', 'Serves': '13', 'Total': '274'}
# {'Rank': '3', 'ShirtNumber': '12', 'Name': 'Stephen Boyer', 'Team': 'FRA', 'Attacks': '224', 'Blocks': '28', 'Serves': '5', 'Total': '257'}
# {'Rank': '4', 'ShirtNumber': '18', 'Name': 'Egor Kliuka', 'Team': 'RUS', 'Attacks': '178', 'Blocks': '28', 'Serves': '18', 'Total': '224'}
# {'Rank': '5', 'ShirtNumber': '13', 'Name': 'Dmitriy Muserskiy', 'Team': 'RUS', 'Attacks': '173', 'Blocks': '32', 'Serves': '17', 'Total': '222'}
# {'Rank': '6', 'ShirtNumber': '1', 'Name': 'Matthew Anderson', 'Team': 'USA', 'Attacks': '182', 'Blocks': '14', 'Serves': '21', 'Total': '217'}
# ...

# %%
import pandas as pd

df = pd.DataFrame(all_data_scr)
df
# Out:
#                      Rank ShirtNumber               Name  Team Attacks Blocks  \
# 0                       1           8   Wallace De Souza   BRA     240     21
# 1                       2           2        Chuan Jiang   CHN     242     19
# 2                       3          12      Stephen Boyer   FRA     224     28
# 3                       4          18        Egor Kliuka   RUS     178     28
# 4                       5          13  Dmitriy Muserskiy   RUS     173     32
# ..                    ...         ...                ...   ...     ...    ...
# 236                   237          15     Bryan Duquette   CAN       1      0
# 237                   238          21  Brett James Walsh   CAN       0      0
# 238                   239           5      Raphaël Corre   FRA       0      1
# 239                   240           7      Meisam Salehi   IRI       1      0
# 240  Total for tournament       12291               2032  1188   15511    NaN
#
#     Serves Total
# ...

# %%
nome = 'vnl_2018_best_scorers.csv'
df.to_csv(nome, index=False)
