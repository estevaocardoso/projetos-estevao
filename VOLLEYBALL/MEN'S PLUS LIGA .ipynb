# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.plusliga.pl/statsPlayers.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D"

payload = {}
headers = {
  'authority': 'www.plusliga.pl',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': 'contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; _ga_52DFT0WK4J=GS1.1.1706876544.2.1.1706877019.0.0.0; _ga=GA1.2.395578836.1706790043; _gat=1; _gat_gtag_UA_3414984_6=1',
  'referer': 'https://www.plusliga.pl/',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload)

content_pg = response.text
source_pg = BeautifulSoup(content_pg, 'lxml')

# %%
links = source_pg.find_all('div', 'thumbnail player')
hrefs = [link.find('a').get('href') for link in links if link.find('a')]
hrefs = [i.split('/')[3].split('.')[0] for i in hrefs]
hrefs[2]
# Out:
# '27975'

# %%
hrefs[:3]
# Out:
# ['2100171', '2124367', '27975']

# %%
import requests
from bs4 import BeautifulSoup
values = []
erros = []



for i in hrefs[:]:

    url = f"https://www.plusliga.pl/statsPlayers/id/{i}.html"


    headers = {
        'authority': 'www.plusliga.pl',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cache-control': 'max-age=0',
        'cookie': 'popshow=1; contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; _ga_52DFT0WK4J=GS1.1.1706878958.3.1.1706879574.0.0.0; _ga=GA1.2.395578836.1706790043',
        'referer': 'https://www.plusliga.pl/statsPlayers.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
        'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
        }

    response = requests.request("GET", url, headers=headers, data=payload)
    content_pg = response.text
    source_pg = BeautifulSoup(content_pg, 'html.parser')
    tbody = source_pg.find('tbody')
    try:
      if tbody:
        biop = {}
        biop['matches_played'] = tbody.find_all('td')[0].text
        biop['sets_played'] = tbody.find_all('td')[1].text
        biop['points'] = tbody.find_all('td')[2].text
        biop['serves'] = tbody.find_all('td')[3].text
        biop['aces'] = tbody.find_all('td')[4].text
        biop['serves_mistakes'] = tbody.find_all('td')[5].text
        biop['aces_per_set'] = tbody.find_all('td')[6].text
        biop['reception'] = tbody.find_all('td')[7].text
        biop['reception_mistakes'] = tbody.find_all('td')[8].text
        biop['reception_bad'] = tbody.find_all('td')[9].text
        biop['reception_perfect'] = tbody.find_all('td')[10].text
        biop['reception_perfect%'] = tbody.find_all('td')[11].text
        biop['attacks'] = tbody.find_all('td')[12].text
        biop['attacks_mistakes'] = tbody.find_all('td')[13].text
        biop['attacks_blocked'] = tbody.find_all('td')[14].text
        biop['attacks_perfect'] = tbody.find_all('td')[15].text
        biop['attacks_perfect%'] = tbody.find_all('td')[16].text
        biop['blocks_points'] = tbody.find_all('td')[17].text
        biop['blocks_points_perset'] = tbody.find_all('td')[18].text
      else:
          print(f"Tabela não encontrada para o jogador {i}.")
    except IndexError as e:
        print(f"Erro ao processar jogador {i}: {e}")
        erros.append(i)
    url1 = f"https://www.plusliga.pl/players/id/{i}.html"

    headers1 = {
      'authority': 'www.plusliga.pl',
      'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
      'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
      'cache-control': 'max-age=0',
      'cookie': 'contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; popshow=1; _ga_52DFT0WK4J=GS1.1.1706883187.4.1.1706883406.0.0.0; _ga=GA1.1.395578836.1706790043',
      'referer': 'https://www.plusliga.pl/players.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
      'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'document',
      'sec-fetch-mode': 'navigate',
      'sec-fetch-site': 'same-origin',
      'sec-fetch-user': '?1',
      'upgrade-insecure-requests': '1',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
    }

    response1 = requests.request("GET", url1, headers=headers1, data=payload)

    content_pg1 = response1.text
    source_pg1 = BeautifulSoup(content_pg1, 'html.parser')
    try:
   
      biop['player_name'] = source_pg1.find_all('h1', class_='playername')[0].text
      biop['player_age'] = source_pg1.find_all('div', class_='datainfo small')[0].text.split(':')[1].replace('.', '/')
      biop['player_height_cm'] = source_pg1.find_all('div', class_='datainfo text-center')[0].text.split(':')[1]
      biop['player_weight_kg'] = source_pg1.find_all('div', class_='datainfo text-center')[1].text.split(':')[1]
      biop['player_jump_height_cm'] = source_pg1.find_all('div', class_='datainfo text-center')[2].text.split(':')[1]
      biop['player_id'] = i
      
      
    except IndexError as e:
        print(f"Erro ao processar jogador {i}: {e}")
        erros.append(i)
    values.append(biop)
    values

# %%
import json

# %%
name = "PLAYERS_BIO_MEN'S_PLUS_LEAGUE_23/24.json"
with open(name, 'w', encoding='utf-8') as json_file:
    json.dump(values, json_file, ensure_ascii=False, indent=2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[89], line 2
#       1 name = "PLAYERS_BIO_MEN'S_PLUS_LEAGUE_23/24.json"
# ----> 2 with open(name, 'w', encoding='utf-8') as json_file:
#       3     json.dump(values, json_file, ensure_ascii=False, indent=2)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: "PLAYERS_BIO_MEN'S_PLUS_LEAGUE_23/24.json"

# %%
import pandas as pd 
df = pd.DataFrame(values)
df_erros = df[df['player_id'].isin(erros)].copy()
df_erros
# Out:
#     matches_played sets_played points serves aces serves_mistakes  \
# 34             NaN         NaN    NaN    NaN  NaN             NaN
# 38             NaN         NaN    NaN    NaN  NaN             NaN
# 42             NaN         NaN    NaN    NaN  NaN             NaN
# 54             NaN         NaN    NaN    NaN  NaN             NaN
# 57             NaN         NaN    NaN    NaN  NaN             NaN
# 61             NaN         NaN    NaN    NaN  NaN             NaN
# 89             NaN         NaN    NaN    NaN  NaN             NaN
# 97             NaN         NaN    NaN    NaN  NaN             NaN
# 135            NaN         NaN    NaN    NaN  NaN             NaN
# 137            NaN         NaN    NaN    NaN  NaN             NaN
# 172            NaN         NaN    NaN    NaN  NaN             NaN
# 180            NaN         NaN    NaN    NaN  NaN             NaN
# 208            NaN         NaN    NaN    NaN  NaN             NaN
# ...

# %%
import requests
from bs4 import BeautifulSoup
values = []
erros = []

biop = {}

for i in hrefs:

    url = f"https://www.plusliga.pl/statsPlayers/id/{i}.html"


    headers = {
        'authority': 'www.plusliga.pl',
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
        'cache-control': 'max-age=0',
        'cookie': 'popshow=1; contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; _ga_52DFT0WK4J=GS1.1.1706878958.3.1.1706879574.0.0.0; _ga=GA1.2.395578836.1706790043',
        'referer': 'https://www.plusliga.pl/statsPlayers.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
        'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
        }

    response = requests.request("GET", url, headers=headers, data=payload)
    content_pg = response.text
    source_pg = BeautifulSoup(content_pg, 'html.parser')
    tbody = source_pg.find('tbody')
    try:
      if tbody:
        biop['matches_played'] = tbody.find_all('td')[0].text
        biop['sets_played'] = tbody.find_all('td')[1].text
        biop['points'] = tbody.find_all('td')[2].text
        biop['serves'] = tbody.find_all('td')[3].text
        biop['aces'] = tbody.find_all('td')[4].text
        biop['serves_mistakes'] = tbody.find_all('td')[5].text
        biop['aces_per_set'] = tbody.find_all('td')[6].text
        biop['reception'] = tbody.find_all('td')[7].text
        biop['reception_mistakes'] = tbody.find_all('td')[8].text
        biop['reception_bad'] = tbody.find_all('td')[9].text
        biop['reception_perfect'] = tbody.find_all('td')[10].text
        biop['reception_perfect%'] = tbody.find_all('td')[11].text
        biop['attacks'] = tbody.find_all('td')[12].text
        biop['attacks_mistakes'] = tbody.find_all('td')[13].text
        biop['attacks_blocked'] = tbody.find_all('td')[14].text
        biop['attacks_perfect'] = tbody.find_all('td')[15].text
        biop['attacks_perfect%'] = tbody.find_all('td')[16].text
        biop['blocks_points'] = tbody.find_all('td')[17].text
        biop['blocks_points_perset'] = tbody.find_all('td')[18].text
      else:
          print(f"Tabela não encontrada para o jogador {i}.")
    except IndexError as e:
        print(f"Erro ao processar jogador {i}: {e}")
        erros.append(i)
    url1 = f"https://www.plusliga.pl/players/id/{i}.html"

    headers1 = {
      'authority': 'www.plusliga.pl',
      'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
      'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
      'cache-control': 'max-age=0',
      'cookie': 'contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; popshow=1; _ga_52DFT0WK4J=GS1.1.1706883187.4.1.1706883406.0.0.0; _ga=GA1.1.395578836.1706790043',
      'referer': 'https://www.plusliga.pl/players.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
      'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'document',
      'sec-fetch-mode': 'navigate',
      'sec-fetch-site': 'same-origin',
      'sec-fetch-user': '?1',
      'upgrade-insecure-requests': '1',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
    }

    response1 = requests.request("GET", url1, headers=headers1, data=payload)

    content_pg1 = response1.text
    source_pg1 = BeautifulSoup(content_pg1, 'html.parser')
    try:
   
      biop['player_name'] = source_pg1.find_all('h1', class_='playername')[0].text
      biop['player_age'] = source_pg1.find_all('div', class_='datainfo small')[0].text.split(':')[1].replace('.', '/')
      biop['player_height_cm'] = source_pg1.find_all('div', class_='datainfo text-center')[0].text.split(':')[1]
      biop['player_weight_kg'] = source_pg1.find_all('div', class_='datainfo text-center')[1].text.split(':')[1]
      biop['player_jump_height_cm'] = source_pg1.find_all('div', class_='datainfo text-center')[2].text.split(':')[1]
      
    except IndexError as e:
        print(f"Erro ao processar jogador {i}: {e}")
        erros.append(i)

    values.append(biop)
    print(f'{i} feito')
