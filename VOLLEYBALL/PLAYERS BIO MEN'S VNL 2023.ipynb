# %%
from bs4 import BeautifulSoup
import requests

url = "https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2023/statistics/men/best-servers/"

payload = {}
headers = {
  'authority': 'en.volleyballworld.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': '_tt_enable_cookie=1; _ttp=mC9cwvZDEfFvm84XhcY_UpCFQS1; __qca=P0-22326168-1696070767255; _hjSessionUser_3054680=eyJpZCI6Ijc5NjFiZWRhLWFiYmItNTFmMi05YjZlLTljMWE4Mjg0Yzk2MiIsImNyZWF0ZWQiOjE2OTYwNzA3ODA1MjcsImV4aXN0aW5nIjp0cnVlfQ==; _vwo_uuid_v2=DB3B3C099E1E6AF8DAD0304C6CC4A4098|a687021c2fb118a0e3b8b34c2e8eef96; _hjSessionUser_1859763=eyJpZCI6IjcwNmIzOWRmLWU2ZWQtNWIyNC04YzgxLWQxYjczMmQxMWU2NCIsImNyZWF0ZWQiOjE2OTYwNzA3NjYxMjIsImV4aXN0aW5nIjp0cnVlfQ==; _ga=GA1.1.173820319.1696070762; _gid=GA1.2.283440947.1696070762; OptanonAlertBoxClosed=2023-09-30T22:00:03.458Z; Language=en; fivbCookies=true; SC_ANALYTICS_GLOBAL_COOKIE=acbe818e7254478b85d066a48829924e|False; _gcl_au=1.1.60668392.1704369909; _fbp=fb.1.1705345778579.1082455755; _gid=GA1.2.283440947.1696070762; _ga_5ZY57D5RSS=GS1.1.1706702476.35.0.1706702476.60.0.0; _ga=GA1.1.173820319.1696070762; _ga_R215V1S3VM=GS1.1.1706702477.17.1.1706702477.60.0.0; OptanonConsent=isIABGlobal=false&datestamp=Wed+Jan+31+2024+09%3A01%3A17+GMT-0300+(Hor%C3%A1rio+Padr%C3%A3o+de+Bras%C3%ADlia)&version=6.18.0&hosts=&consentId=99d3274d-8d3a-4770-9823-42325ef10494&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=BR%3BPE; _hjSession_1859763=eyJpZCI6IjNiZjg2YTQ3LTAyOTktNDM1MC04ZTgwLTRkYzE4YzVkNTYzOSIsImMiOjE3MDY3MDI0Nzc0MzUsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; _ga_0XQMFZ8Y93=GS1.2.1706702477.22.1.1706702477.0.0.0',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload)

content = response.text
soup = BeautifulSoup(content, 'lxml')

# %%
p = soup.find_all('tr', class_='vbw-o-table__row')
lp = []
values = []
for element in p:
    lp.append(element['data-player-no'])
con = 0

for i in lp[:]:
    print(f'we are doing the {i} player')
    url = f"https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2023/players/{i}"

    payload = {}
    headers = {
          'authority': 'en.volleyballworld.com',
          'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
          'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
          'cache-control': 'max-age=0',
          'cookie': '_tt_enable_cookie=1; _ttp=mC9cwvZDEfFvm84XhcY_UpCFQS1; __qca=P0-22326168-1696070767255; _hjSessionUser_3054680=eyJpZCI6Ijc5NjFiZWRhLWFiYmItNTFmMi05YjZlLTljMWE4Mjg0Yzk2MiIsImNyZWF0ZWQiOjE2OTYwNzA3ODA1MjcsImV4aXN0aW5nIjp0cnVlfQ==; _vwo_uuid_v2=DB3B3C099E1E6AF8DAD0304C6CC4A4098|a687021c2fb118a0e3b8b34c2e8eef96; _hjSessionUser_1859763=eyJpZCI6IjcwNmIzOWRmLWU2ZWQtNWIyNC04YzgxLWQxYjczMmQxMWU2NCIsImNyZWF0ZWQiOjE2OTYwNzA3NjYxMjIsImV4aXN0aW5nIjp0cnVlfQ==; _ga=GA1.1.173820319.1696070762; _gid=GA1.2.283440947.1696070762; OptanonAlertBoxClosed=2023-09-30T22:00:03.458Z; Language=en; fivbCookies=true; SC_ANALYTICS_GLOBAL_COOKIE=acbe818e7254478b85d066a48829924e|False; _gcl_au=1.1.60668392.1704369909; _fbp=fb.1.1705345778579.1082455755; _gid=GA1.2.283440947.1696070762; _hjSession_1859763=eyJpZCI6IjYwNjA5NzYzLWM1YTItNDM5Ny1hMDRjLTAxODlmNGM0ZGQwOCIsImMiOjE3MDY3ODQwOTM4NzMsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; OptanonConsent=isIABGlobal=false&datestamp=Thu+Feb+01+2024+07%3A43%3A23+GMT-0300+(Hor%C3%A1rio+Padr%C3%A3o+de+Bras%C3%ADlia)&version=6.18.0&hosts=&consentId=99d3274d-8d3a-4770-9823-42325ef10494&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=BR%3BPE; _ga=GA1.1.173820319.1696070762; _ga_R215V1S3VM=GS1.1.1706784094.18.1.1706784203.13.0.0; _ga_5ZY57D5RSS=GS1.1.1706784093.38.1.1706784203.12.0.0; _ga_0XQMFZ8Y93=GS1.2.1706784094.23.1.1706784203.0.0.0',
          'referer': 'https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2023/finals-statistics/men/best-blockers/',
          'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
          'sec-ch-ua-mobile': '?0',
          'sec-ch-ua-platform': '"Windows"',
          'sec-fetch-dest': 'document',
          'sec-fetch-mode': 'navigate',
          'sec-fetch-site': 'same-origin',
          'sec-fetch-user': '?1',
          'upgrade-insecure-requests': '1',
          'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
        }

    response = requests.request("GET", url, headers=headers, data=payload)
    content = response.text
    source_pg = BeautifulSoup(content, 'lxml')
    info = source_pg.find_all('div', class_='vbw-player-bio-col')
    try:
      bio = {}
      bio['number_player'] = source_pg.find('div', class_='vbw-player-no').text
      bio['name_player'] = source_pg.find('span', class_='vbw-player-name').text + " " + source_pg.find('span', class_='vbw-player-lastname').text
      bio['position'] = source_pg.find('div', class_='vbw-player-bio-text').text
      bio['nationality'] = source_pg.find_all('div', class_='vbw-player-bio-text')[2].text
      bio['age'] = source_pg.find_all('div', class_='vbw-player-bio-text')[4].text
      bio['height cm'] = source_pg.find_all('div', class_='vbw-player-bio-text')[6].text.split('c')[0]
      bio['weight Kg'] = source_pg.find_all('div', class_='vbw-player-bio-text')[7].text.split('K')[0]
      bio['player_id'] = i
      
      values.append(bio)
    
    except:
       print(f"the player {i} was not found")
# Out:
# we are doing the 137498 player
# we are doing the 162520 player
# we are doing the 142568 player
# we are doing the 169940 player
# we are doing the 162546 player
# we are doing the 136468 player
# we are doing the 114957 player
# we are doing the 168271 player
# we are doing the 118893 player
# we are doing the 151817 player
# we are doing the 162122 player
# we are doing the 139254 player
# we are doing the 163038 player
# we are doing the 178762 player
# we are doing the 153539 player
# we are doing the 119646 player
# we are doing the 143794 player
# we are doing the 132624 player
# we are doing the 171191 player
# we are doing the 152405 player
# we are doing the 152870 player
# we are doing the 163519 player
# we are doing the 152692 player
# we are doing the 150734 player
# we are doing the 170436 player
# we are doing the 162081 player
# we are doing the 136291 player
# we are doing the 151391 player
# we are doing the 168747 player
# we are doing the 139929 player
# we are doing the 151871 player
# we are doing the 136918 player
# we are doing the 118901 player
# we are doing the 152469 player
# we are doing the 139386 player
# we are doing the 162082 player
# we are doing the 152869 player
# we are doing the 156676 player
# we are doing the 152752 player
# we are doing the 140061 player
# we are doing the 125010 player
# we are doing the 144005 player
# we are doing the 152408 player
# we are doing the 180586 player
# we are doing the 142415 player
# we are doing the 140042 player
# we are doing the 140428 player
# we are doing the 146579 player
# we are doing the 142686 player
# we are doing the 136856 player
# we are doing the 156678 player
# we are doing the 136947 player
# we are doing the 143682 player
# we are doing the 136851 player
# we are doing the 163555 player
# we are doing the 181100 player
# we are doing the 163309 player
# we are doing the 170104 player
# we are doing the 148120 player
# we are doing the 116069 player
# we are doing the 153200 player
# we are doing the 142694 player
# we are doing the 180587 player
# we are doing the 152518 player
# we are doing the 174159 player
# we are doing the 133009 player
# we are doing the 174373 player
# we are doing the 174076 player
# we are doing the 153395 player
# we are doing the 161930 player
# we are doing the 132022 player
# we are doing the 116081 player
# we are doing the 173067 player
# we are doing the 142855 player
# we are doing the 181103 player
# we are doing the 168175 player
# we are doing the 169310 player
# we are doing the 142565 player
# we are doing the 146409 player
# we are doing the 168562 player
# we are doing the 182470 player
# we are doing the 152742 player
# we are doing the 163033 player
# we are doing the 117457 player
# we are doing the 157318 player
# we are doing the 173251 player
# we are doing the 164985 player
# we are doing the 142676 player
# we are doing the 183853 player
# we are doing the 142677 player
# we are doing the 124879 player
# we are doing the 116099 player
# we are doing the 136441 player
# we are doing the 182679 player
# we are doing the 152494 player
# we are doing the 120735 player
# we are doing the 142679 player
# we are doing the 152619 player
# we are doing the 168268 player
# we are doing the 173184 player
# we are doing the 174297 player
# we are doing the 118827 player
# we are doing the 172962 player
# we are doing the 174853 player
# we are doing the 141282 player
# we are doing the 162543 player
# we are doing the 165212 player
# we are doing the 147273 player
# we are doing the 147263 player
# we are doing the 114962 player
# we are doing the 173250 player
# we are doing the 141546 player
# we are doing the 150703 player
# we are doing the 150742 player
# we are doing the 132948 player
# we are doing the 168269 player
# we are doing the 152755 player
# we are doing the 163447 player
# we are doing the 157324 player
# we are doing the 151814 player
# we are doing the 152880 player
# we are doing the 118618 player
# we are doing the 124518 player
# we are doing the 147721 player
# we are doing the 133463 player
# we are doing the 136956 player
# we are doing the 119775 player
# we are doing the 116575 player
# we are doing the 162790 player
# we are doing the 174660 player
# we are doing the 143745 player
# we are doing the 154521 player
# we are doing the 115806 player
# we are doing the 142710 player
# we are doing the 162105 player
# we are doing the 165942 player
# we are doing the 137012 player
# we are doing the 174445 player
# we are doing the 182707 player
# we are doing the 123413 player
# we are doing the 142412 player
# we are doing the 142410 player
# we are doing the 168914 player
# we are doing the 168412 player
# we are doing the 168417 player
# we are doing the 155920 player
# we are doing the 119018 player
# we are doing the 115794 player
# we are doing the 183851 player
# we are doing the 119791 player
# we are doing the 147421 player
# we are doing the 188784 player
# we are doing the 131980 player
# we are doing the 174908 player
# we are doing the 159380 player
# we are doing the 150382 player
# we are doing the 137345 player
# we are doing the 137337 player
# we are doing the 152511 player
# we are doing the 161921 player
# we are doing the 124865 player
# we are doing the 152388 player
# we are doing the 125073 player
# we are doing the 119779 player
# we are doing the 118486 player
# we are doing the 136077 player
# we are doing the 192453 player
# we are doing the 118487 player
# we are doing the 132035 player
# we are doing the 135372 player
# we are doing the 132033 player
# we are doing the 174459 player
# we are doing the 164632 player
# we are doing the 158965 player
# we are doing the 158967 player
# we are doing the 174158 player
# we are doing the 118822 player
# we are doing the 142561 player
# we are doing the 178761 player
# we are doing the 180990 player
# we are doing the 172893 player
# we are doing the 189064 player
# we are doing the 163173 player
# we are doing the 163176 player
# we are doing the 142759 player
# we are doing the 119750 player
# we are doing the 181182 player
# we are doing the 172961 player
# we are doing the 115843 player
# we are doing the 150436 player
# we are doing the 152422 player
# we are doing the 163028 player
# we are doing the 163032 player
# we are doing the 150435 player
# we are doing the 163025 player
# we are doing the 174074 player
# we are doing the 142411 player
# we are doing the 153053 player
# we are doing the 160816 player
# we are doing the 125047 player
# we are doing the 124553 player
# we are doing the 136296 player
# we are doing the 183276 player
# we are doing the 168925 player
# we are doing the 168923 player
# we are doing the 168908 player
# we are doing the 132361 player
# we are doing the 147268 player
# we are doing the 157477 player
# we are doing the 147272 player
# we are doing the 182877 player
# we are doing the 190322 player
# we are doing the 168715 player
# we are doing the 151405 player
# we are doing the 161756 player
# we are doing the 157872 player
# we are doing the 151404 player
# we are doing the 144483 player
# we are doing the 144415 player
# we are doing the 136360 player
# we are doing the 192041 player
# we are doing the 132458 player
# we are doing the 173249 player
# we are doing the 200747 player
# we are doing the 200748 player
# we are doing the 196710 player
# we are doing the 168276 player
# we are doing the 164127 player
# we are doing the 182509 player
# we are doing the 165953 player
# we are doing the 164124 player
# we are doing the 153387 player
# we are doing the 183117 player
# we are doing the 136855 player
# we are doing the 189664 player
# we are doing the 152506 player
# we are doing the 142659 player
# we are doing the 191228 player
# we are doing the 189662 player
# we are doing the 164027 player
# we are doing the 147417 player
# we are doing the 119732 player
# we are doing the 153472 player
# we are doing the 188782 player
# we are doing the 169921 player
# we are doing the 121992 player
# we are doing the 181317 player
# we are doing the 184894 player
# we are doing the 188785 player
# we are doing the 142744 player
# we are doing the 161939 player
# we are doing the 118916 player
# we are doing the 178341 player
# we are doing the 182323 player
# we are doing the 187493 player
# we are doing the 182291 player
# we are doing the 152349 player
# we are doing the 163592 player
# we are doing the 152352 player
# we are doing the 184322 player
# we are doing the 163516 player
# we are doing the 162557 player
# we are doing the 136442 player
# we are doing the 162083 player
# we are doing the 142445 player
# we are doing the 147543 player
# we are doing the 142420 player
# we are doing the 182325 player
# we are doing the 174295 player
# we are doing the 113691 player
# we are doing the 124986 player
# we are doing the 164812 player
# we are doing the 152370 player
# we are doing the 181128 player
# we are doing the 172958 player
# we are doing the 164117 player
# we are doing the 118614 player
# we are doing the 152866 player
# we are doing the 150741 player
# we are doing the 119792 player
# we are doing the 164031 player
# we are doing the 151789 player
# we are doing the 152412 player
# we are doing the 174531 player
# we are doing the 142562 player
# we are doing the 189039 player
# we are doing the 142598 player
# we are doing the 124926 player
# we are doing the 116525 player
# we are doing the 153535 player
# we are doing the 152753 player
# we are doing the 189602 player
# we are doing the 168551 player
# we are doing the 119804 player
# we are doing the 153388 player
# we are doing the 163174 player
# we are doing the 118928 player

# %%
name = "PLAYERS_BIO_MEN'S_VNL_2023.json"
import json

with open(name, 'w', encoding='utf-8') as json_file:
    json.dump(values, json_file, ensure_ascii=False, indent=2)
