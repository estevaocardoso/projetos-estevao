762; OptanonAlertBoxClosed=2023-09-30T22:00:03.458Z; Language=en; fivbCookies=true; SC_ANALYTICS_GLOBAL_COOKIE=acbe818e7254478b85d066a48829924e|False; _gcl_au=1.1.60668392.1704369909; _fbp=fb.1.1705345778579.1082455755; _gid=GA1.2.283440947.1696070762; _ga_5ZY57D5RSS=GS1.1.1706702476.35.0.1706702476.60.0.0; _ga=GA1.1.173820319.1696070762; _ga_R215V1S3VM=GS1.1.1706702477.17.1.1706702477.60.0.0; OptanonConsent=isIABGlobal=false&datestamp=Wed+Jan+31+2024+09%3A01%3A17+GMT-0300+(Hor%C3%A1rio+Padr%C3%A3o+de+Bras%C3%ADlia)&version=6.18.0&hosts=&consentId=99d3274d-8d3a-4770-9823-42325ef10494&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=BR%3BPE; _hjSession_1859763=eyJpZCI6IjNiZjg2YTQ3LTAyOTktNDM1MC04ZTgwLTRkYzE4YzVkNTYzOSIsImMiOjE3MDY3MDI0Nzc0MzUsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; _ga_0XQMFZ8Y93=GS1.2.1706702477.22.1.1706702477.0.0.0',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload)

content = response.text
soup1 = BeautifulSoup(content, 'lxml')

# %%
headers = [th.text for th in soup.find_all('th')]
tbody = soup.find('tbody')
rows = [[tr.get_text(strip=True) for tr in row] for row in tbody]
player_id = soup.find('tr', {'vbw-o-table__row vbw-o-table__row--scorer vbw-stats-player':'data-player-no'})

table = [dict(zip(headers, row)) for row in rows]

# %%
p = soup.find_all('tr', class_='vbw-o-table__row')
p1 = soup1.find_all('tr', class_='vbw-o-table__row')
lp = []
lp1 = []
values = []
for element in p:
    lp.append(element['data-player-no'])
for element1 in p1:
    lp1.append(element1['data-player-no'])

all_elements_match = all(element in lp1 for element in lp)

if all_elements_match:
    print("Todos os elementos em lp têm um equivalente em lp1.")
else:
    print("Pelo menos um elemento em lp não tem um equivalente em lp1.")
# Out:
# Todos os elementos em lp têm um equivalente em lp1.

# %%
p = soup.find_all('tr', class_='vbw-o-table__row')
lp = []
values = []
for element in p:
    lp.append(element['data-player-no'])
con = 0

for i in lp[:3]:
    print(f'we are doing the {i} player')
    url = f"https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2023/players/{i}"

    payload = {}
    headers = {
          'authority': 'en.volleyballworld.com',
          'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
          'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
          'cache-control': 'max-age=0',
          'cookie': '_tt_enable_cookie=1; _ttp=mC9cwvZDEfFvm84XhcY_UpCFQS1; __qca=P0-22326168-1696070767255; _hjSessionUser_3054680=eyJpZCI6Ijc5NjFiZWRhLWFiYmItNTFmMi05YjZlLTljMWE4Mjg0Yzk2MiIsImNyZWF0ZWQiOjE2OTYwNzA3ODA1MjcsImV4aXN0aW5nIjp0cnVlfQ==; _vwo_uuid_v2=DB3B3C099E1E6AF8DAD0304C6CC4A4098|a687021c2fb118a0e3b8b34c2e8eef96; _hjSessionUser_1859763=eyJpZCI6IjcwNmIzOWRmLWU2ZWQtNWIyNC04YzgxLWQxYjczMmQxMWU2NCIsImNyZWF0ZWQiOjE2OTYwNzA3NjYxMjIsImV4aXN0aW5nIjp0cnVlfQ==; _ga=GA1.1.173820319.1696070762; _gid=GA1.2.283440947.1696070762; OptanonAlertBoxClosed=2023-09-30T22:00:03.458Z; Language=en; fivbCookies=true; SC_ANALYTICS_GLOBAL_COOKIE=acbe818e7254478b85d066a48829924e|False; _gcl_au=1.1.60668392.1704369909; _fbp=fb.1.1705345778579.1082455755; _gid=GA1.2.283440947.1696070762; _hjSession_1859763=eyJpZCI6IjYwNjA5NzYzLWM1YTItNDM5Ny1hMDRjLTAxODlmNGM0ZGQwOCIsImMiOjE3MDY3ODQwOTM4NzMsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; OptanonConsent=isIABGlobal=false&datestamp=Thu+Feb+01+2024+07%3A43%3A23+GMT-0300+(Hor%C3%A1rio+Padr%C3%A3o+de+Bras%C3%ADlia)&version=6.18.0&hosts=&consentId=99d3274d-8d3a-4770-9823-42325ef10494&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=BR%3BPE; _ga=GA1.1.173820319.1696070762; _ga_R215V1S3VM=GS1.1.1706784094.18.1.1706784203.13.0.0; _ga_5ZY57D5RSS=GS1.1.1706784093.38.1.1706784203.12.0.0; _ga_0XQMFZ8Y93=GS1.2.1706784094.23.1.1706784203.0.0.0',
          'referer': 'https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2023/finals-statistics/men/best-blockers/',
          'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
          'sec-ch-ua-mobile': '?0',
          'sec-ch-ua-platform': '"Windows"',
          'sec-fetch-dest': 'document',
          'sec-fetch-mode': 'navigate',
          'sec-fetch-site': 'same-origin',
          'sec-fetch-user': '?1',
          'upgrade-insecure-requests': '1',
          'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
        }

    response = requests.request("GET", url, headers=headers, data=payload)
    content = response.text
    source_pg = BeautifulSoup(content, 'lxml')
    info = source_pg.find_all('div', class_='vbw-player-bio-col')
    try:
      bio = {}
      bio['number_player'] = source_pg.find('div', class_='vbw-player-no').text
      bio['name_player'] = source_pg.find('span', class_='vbw-player-name').text + " " + source_pg.find('span', class_='vbw-player-lastname').text
      bio['position'] = source_pg.find('div', class_='vbw-player-bio-text').text
      bio['nationality'] = source_pg.find_all('div', class_='vbw-player-bio-text')[2].text
      bio['age'] = source_pg.find_all('div', class_='vbw-player-bio-text')[4].text
      bio['height cm'] = source_pg.find_all('div', class_='vbw-player-bio-text')[6].text.split('c')[0]
      bio['weight Kg'] = source_pg.find_all('div', class_='vbw-player-bio-text')[7].text.split('K')[0]
      bio['player_id'] = i
      
      values.append(bio)
    
    except:
       print(f"the player {i} was not found")
# Out:
# we are doing the 137498 player
# we are doing the 162520 player
# we are doing the 142568 player

# %%
values
# Out:
# [{'number_player': '14',
#   'name_player': 'Nimir Abdel-Aziz',
#   'position': 'Opposite spiker',
#   'nationality': 'Netherlands',
#   'age': '31',
#   'height cm': '201',
#   'weight Kg': '91',
#   'player_id': '137498'},
#  {'number_player': '16',
#   'name_player': 'Yuri Romanò',
#   'position': 'Opposite spiker',
#   'nationality': 'Italy',
#   'age': '26',
#   'height cm': '201',
#   'weight Kg': '89',
#   'player_id': '162520'},
#  {'number_player': '14',
#   'name_player': 'Yuki Ishikawa',
#   'position': 'Outside Hitter',
#   'nationality': 'Japan',
#   'age': '28',
#   'height cm': '191',
#   'weight Kg': '84',
#   'player_id': '142568'}]

# %%
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
df = pd.DataFrame(values)
df
# Out:
#     number_player           name_player         position    nationality age  \
# 0              14         Yuki Ishikawa   Outside Hitter          Japan  28
# 1              16           Yuri Romanò  Opposite spiker          Italy  26
# 2              14      Nimir Abdel-Aziz  Opposite spiker    Netherlands  31
# 3              12   Jesus Herrera Jaime  Opposite spiker           Cuba  28
# 4              12         Ran Takahashi   Outside Hitter          Japan  22
# ..            ...                   ...              ...            ...  ..
# 292             9  Mohammadreza Moazzen           Libero           Iran  32
# 293             3       Jakub Popiwczak           Libero         Poland  27
# 294            19         Marcin Janusz           Setter         Poland  29
# 295            15          Kyle Russell  Opposite spiker  United States  30
# 296            77     Ehsan Daneshdoust   Outside Hitter           Iran  24
#
#     height cm weight Kg
# 0         191        84
# ...

# %%
df_sorted = df.sort_values(by='height cm', ascending=False)
df['height cm'] = df['height cm'].astype(int)
grouped_df = df.groupby('position')['height cm'].mean().reset_index()

plt.bar(grouped_df['position'], grouped_df['height cm'])

plt.xlabel('Average Heigh (cm)')
plt.ylabel('Position')
plt.xticks(rotation=20)
plt.title('Average height by position')
plt.show()

# %%
import pandas as pd
df = pd.read_json("MEN'S_VNL_2023_FINALS.json")
df = pd.DataFrame(df['tabela'][0])
df
# Out:
#     Shirt NumberShirt                Player NamePlayer TeamTeam PointsPts  \
# 0                  14                    Ishikawa Yuki      JPN        70
# 1                   1                 Anderson Matthew      USA        49
# 2                   5                 Kaczmarek Lukasz      POL        47
# 3                  11                Sliwka Aleksander      POL        44
# 4                  17                  Jaeschke Thomas      USA        41
# ..                ...                              ...      ...       ...
# 108                14             Gil Kreling Fernando      BRA         0
# 109                15           Nascimento Maique Reis      BRA         0
# 110                17                      Hoss Thales      BRA         0
# 111                30  Nunes da Cunha Jr Judson Amabel      BRA         0
# 112                28              Evbade-Dan Larry Ik      JPN         0
#
#     Attack PointsA Pts Block PointsB Pts Serve PointsS Pts  \
# ...

# %%
import matplotlib.pyplot as plt

df['PointsPts'] = df['PointsPts'].astype(int)
df_sorted = df.sort_values(by="PointsPts", ascending=False) 

top_20 = df_sorted.head(20)
plt.figure(figsize=(10,8))
plt.bar(top_20['Player NamePlayer'], top_20['PointsPts'], color='skyblue')  # Usando bar em vez de barh
plt.xlabel('Players')
plt.ylabel('Points')
plt.title('Top 20 Players - Total Points')
plt.xticks(rotation=90)  # Rotação dos nomes dos jogadores para melhor visualização
plt.show()

# %%
df_sorted
# Out:
#     Shirt NumberShirt    Player NamePlayer TeamTeam PointsPts  \
# 34                 18       Äebulj Klemen      SLO         9
# 36                 21        Fornal Tomasz      POL         8
# 35                 19       Averill Taylor      USA         8
# 0                  14        Ishikawa Yuki      JPN        70
# 37                 17      Clevenot Trevor      FRA         7
# ..                ...                  ...      ...       ...
# 83                  4      Gallego Joaquin      ARG         0
# 84                  9      Danani Santiago      ARG         0
# 85                 12           Lima Bruno      ARG         0
# 86                 15     De Cecco Luciano      ARG         0
# 112                28  Evbade-Dan Larry Ik      JPN         0
#
#     Attack PointsA Pts Block PointsB Pts Serve PointsS Pts  \
# 34                   8                 1                 0
# 36                   7                 1                 0
# ...
