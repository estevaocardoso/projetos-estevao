# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2022/statistics/men/best-scorers/"

payload = {}
headers = {
  'authority': 'en.volleyballworld.com',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': '_tt_enable_cookie=1; _ttp=mC9cwvZDEfFvm84XhcY_UpCFQS1; __qca=P0-22326168-1696070767255; _hjSessionUser_3054680=eyJpZCI6Ijc5NjFiZWRhLWFiYmItNTFmMi05YjZlLTljMWE4Mjg0Yzk2MiIsImNyZWF0ZWQiOjE2OTYwNzA3ODA1MjcsImV4aXN0aW5nIjp0cnVlfQ==; _vwo_uuid_v2=DB3B3C099E1E6AF8DAD0304C6CC4A4098|a687021c2fb118a0e3b8b34c2e8eef96; _hjSessionUser_1859763=eyJpZCI6IjcwNmIzOWRmLWU2ZWQtNWIyNC04YzgxLWQxYjczMmQxMWU2NCIsImNyZWF0ZWQiOjE2OTYwNzA3NjYxMjIsImV4aXN0aW5nIjp0cnVlfQ==; _ga=GA1.1.173820319.1696070762; _gid=GA1.2.283440947.1696070762; OptanonAlertBoxClosed=2023-09-30T22:00:03.458Z; Language=en; fivbCookies=true; _gcl_au=1.1.60668392.1704369909; _fbp=fb.1.1705345778579.1082455755; _gid=GA1.2.283440947.1696070762; vnl2018#lang=en; vnl2019#lang=en; SC_ANALYTICS_GLOBAL_COOKIE=347da2e70e894c9ca41a1195e37c03ce|False; _hjSession_1859763=eyJpZCI6ImNkYzQ2ODIzLTBkMTItNGM0MC1hODZiLTM3YTdiODM5MTVlYSIsImMiOjE3MDY4NDEwMjYwNzUsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; OptanonConsent=isIABGlobal=false&datestamp=Thu+Feb+01+2024+23%3A31%3A26+GMT-0300+(Hor%C3%A1rio+Padr%C3%A3o+de+Bras%C3%ADlia)&version=6.18.0&hosts=&consentId=99d3274d-8d3a-4770-9823-42325ef10494&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=BR%3BPE; _ga_R215V1S3VM=GS1.1.1706841025.21.1.1706841086.60.0.0; _ga_5ZY57D5RSS=GS1.1.1706841025.43.1.1706841086.59.0.0; _ga=GA1.2.173820319.1696070762; _gat_UA-185656906-1=1; _ga_0XQMFZ8Y93=GS1.2.1706841026.26.1.1706841086.0.0.0',
  'referer': 'https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2022/statistics/',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload)

content = response.text
soup = BeautifulSoup(content, 'lxml')

# %%
en = soup.find_all('tr', class_='vbw-o-table__row')
id = []
for i in en:
   var = i['data-player-no']
   id.append(var)

# %%
import requests
from bs4 import BeautifulSoup
values = []
for i in id[:]:
    print(f'fazendo o jogador {i}')

    url = f"https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2022/players/{i}"

    payload = {}
    headers = {
    'authority': 'en.volleyballworld.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': '_tt_enable_cookie=1; _ttp=mC9cwvZDEfFvm84XhcY_UpCFQS1; __qca=P0-22326168-1696070767255; _hjSessionUser_3054680=eyJpZCI6Ijc5NjFiZWRhLWFiYmItNTFmMi05YjZlLTljMWE4Mjg0Yzk2MiIsImNyZWF0ZWQiOjE2OTYwNzA3ODA1MjcsImV4aXN0aW5nIjp0cnVlfQ==; _vwo_uuid_v2=DB3B3C099E1E6AF8DAD0304C6CC4A4098|a687021c2fb118a0e3b8b34c2e8eef96; _hjSessionUser_1859763=eyJpZCI6IjcwNmIzOWRmLWU2ZWQtNWIyNC04YzgxLWQxYjczMmQxMWU2NCIsImNyZWF0ZWQiOjE2OTYwNzA3NjYxMjIsImV4aXN0aW5nIjp0cnVlfQ==; _ga=GA1.1.173820319.1696070762; _gid=GA1.2.283440947.1696070762; OptanonAlertBoxClosed=2023-09-30T22:00:03.458Z; Language=en; fivbCookies=true; _gcl_au=1.1.60668392.1704369909; _fbp=fb.1.1705345778579.1082455755; _gid=GA1.2.283440947.1696070762; vnl2018#lang=en; vnl2019#lang=en; SC_ANALYTICS_GLOBAL_COOKIE=347da2e70e894c9ca41a1195e37c03ce|False; _hjSession_1859763=eyJpZCI6ImNkYzQ2ODIzLTBkMTItNGM0MC1hODZiLTM3YTdiODM5MTVlYSIsImMiOjE3MDY4NDEwMjYwNzUsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; _ga_R215V1S3VM=GS1.1.1706841025.21.1.1706841125.21.0.0; OptanonConsent=isIABGlobal=false&datestamp=Thu+Feb+01+2024+23%3A32%3A06+GMT-0300+(Hor%C3%A1rio+Padr%C3%A3o+de+Bras%C3%ADlia)&version=6.18.0&hosts=&consentId=99d3274d-8d3a-4770-9823-42325ef10494&interactionCount=2&landingPath=NotLandingPage&groups=C0001%3A1%2CC0004%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=BR%3BPE; _ga_5ZY57D5RSS=GS1.1.1706841025.43.1.1706841126.19.0.0; _ga=GA1.1.173820319.1696070762; _ga_0XQMFZ8Y93=GS1.2.1706841026.26.1.1706841127.0.0.0',
    'referer': 'https://en.volleyballworld.com/volleyball/competitions/volleyball-nations-league/2022/statistics/men/best-scorers/',
    'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    try:
        content_pg = response.text
        source_pg = BeautifulSoup(content_pg, 'lxml')

        playerid = {}
        playerid['player_num'] = source_pg.find('div', class_='vbw-player-no').text
        playerid['player_name'] = source_pg.find('h3', class_='vbw-player-name').text +" "+source_pg.find('h3', class_='vbw-player-lastname').text 
        playerid['position'] = source_pg.find_all('div', class_='vbw-player-bio-text --desktop')[0].text
        playerid['nationality'] = source_pg.find_all('div', class_='vbw-player-bio-text --desktop')[1].text
        playerid['age'] = source_pg.find_all('div', class_='vbw-player-bio-text')[4].text
        playerid['height_cm'] = source_pg.find_all('div', class_='vbw-player-bio-text')[6].text.split('c')[0]
        playerid['wheight_kg'] = source_pg.find_all('div', class_='vbw-player-bio-text')[7].text.split('K')[0]
        playerid['playerid'] = i
        values.append(playerid)
    except:
        print(f'jogador {i} não feito')
# Out:
# fazendo o jogador 137498
# fazendo o jogador 153539
# fazendo o jogador 163519
# fazendo o jogador 132624
# fazendo o jogador 139254
# fazendo o jogador 180586
# fazendo o jogador 142568
# fazendo o jogador 140061
# fazendo o jogador 147417
# fazendo o jogador 142415
# fazendo o jogador 168271
# fazendo o jogador 174192
# fazendo o jogador 125048
# fazendo o jogador 153200
# fazendo o jogador 136751
# fazendo o jogador 162520
# fazendo o jogador 168747
# fazendo o jogador 156676
# fazendo o jogador 119800
# fazendo o jogador 142694
# fazendo o jogador 115806
# fazendo o jogador 152752
# fazendo o jogador 173251
# fazendo o jogador 119779
# fazendo o jogador 152692
# fazendo o jogador 162082
# fazendo o jogador 170436
# fazendo o jogador 171191
# fazendo o jogador 162122
# fazendo o jogador 136947
# fazendo o jogador 118928
# fazendo o jogador 116069
# fazendo o jogador 136956
# fazendo o jogador 147721
# fazendo o jogador 142710
# fazendo o jogador 153395
# fazendo o jogador 140428
# ...

# %%
values
# Out:
# [{'player_num': '14',
#   'player_name': 'Nimir Abdel-Aziz',
#   'position': 'Opposite spiker',
#   'nationality': 'Netherlands',
#   'age': '31',
#   'height_cm': '201',
#   'wheight_kg': '91',
#   'playerid': '137498'},
#  {'player_num': '17',
#   'player_name': 'Amin Esmaeilnezhad',
#   'position': 'Opposite spiker',
#   'nationality': 'Iran',
#   'age': '27',
#   'height_cm': '203',
#   'wheight_kg': '96',
#   'playerid': '153539'},
#  {'player_num': '1',
#   'player_name': 'Yuji Nishida',
#   'position': 'Opposite spiker',
#   'nationality': 'Japan',
#   'age': '24',
#   'height_cm': '187',
#   'wheight_kg': '89',
#   'playerid': '163519'},
#  {'player_num': '2',
#   'player_name': 'Aaron Russell',
#   'position': 'Outside Hitter',
#   'nationality': 'United States',
#   'age': '30',
#   'height_cm': '205',
#   'wheight_kg': '98',
#   'playerid': '132624'},
#  {'player_num': '8',
#   'player_name': 'Torey Defalco',
#   'position': 'Outside Hitter',
# ...

# %%
import json
name = "PLAYERS_BIO_MEN'S_VNL_2022.json"
with open(name, 'w', encoding='utf-8') as json_file:
    json.dump(values, json_file, ensure_ascii=False, indent=2)
