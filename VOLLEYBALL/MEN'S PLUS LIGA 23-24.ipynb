# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.plusliga.pl/statsPlayers/tournament_1/2023.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D"

payload = {}
headers = {
  'authority': 'www.plusliga.pl',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': 'contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; popshow=1; _ga_52DFT0WK4J=GS1.1.1706921703.7.1.1706921816.0.0.0; _ga=GA1.2.395578836.1706790043',
  'referer': 'https://www.plusliga.pl/statsPlayers/tournament_1/2022.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}

response = requests.request("GET", url, headers=headers, data=payload)

response = requests.request("GET", url, headers=headers, data=payload)

content_pg = response.text
source_pg = BeautifulSoup(content_pg, 'lxml')

links = source_pg.find_all('div', 'thumbnail player')
hrefs = [link.find('a').get('href') for link in links if link.find('a')]
hrefs = [i.split('/')[3].split('.')[0] for i in hrefs]
hrefs

# %%
import requests
from bs4 import BeautifulSoup
values = []
erros = []



for i in hrefs[:]:

    url = f"https://www.plusliga.pl/statsPlayers/id/{i}.html"

    payload = {}
    headers = {
  'authority': 'www.plusliga.pl',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': 'popshow=1; contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; popshow=1; _ga_52DFT0WK4J=GS1.1.1706921703.7.1.1706922140.0.0.0; _ga=GA1.2.395578836.1706790043; _gat=1; _gat_gtag_UA_3414984_6=1',
  'referer': 'https://www.plusliga.pl/statsPlayers/tournament_1/2023.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}

    response = requests.request("GET", url, headers=headers, data=payload)


    content_pg = response.text
    source_pg = BeautifulSoup(content_pg, 'html.parser')
    tbody = source_pg.find_all('tbody')[1]
    rows = tbody.find_all('tr')[-2]
    try:
      if tbody:
        biop = {}
        biop['matches_played'] = [i.text for i in rows][1].split('(')[1].split(')')[0]
        biop['sets_played'] = [i.text for i in rows][3]
        biop['points'] = [i.text for i in rows][5]
        biop['serves'] = [i.text for i in rows][7]
        biop['aces'] = [i.text for i in rows][9]
        biop['serves_mistakes'] = [i.text for i in rows][11]
        biop['aces_per_set'] = [i.text for i in rows][13]
        biop['reception'] = [i.text for i in rows][15]
        biop['reception_mistakes'] = [i.text for i in rows][17]
        biop['reception_bad'] = [i.text for i in rows][19]
        biop['reception_perfect'] = [i.text for i in rows][21]
        biop['reception_perfect%'] = [i.text for i in rows][23]
        biop['attacks'] = [i.text for i in rows][25]
        biop['attacks_mistakes'] = [i.text for i in rows][27]
        biop['attacks_blocked'] = [i.text for i in rows][29]
        biop['attacks_perfect'] = [i.text for i in rows][31]
        biop['attacks_perfect%'] = [i.text for i in rows][33]
        biop['blocks_points'] = [i.text for i in rows][35]
        biop['blocks_points_perset'] = [i.text for i in rows][37]
      else:
          print(f"Tabela não encontrada para o jogador {i}.")
    except IndexError as e:
        print(f"Erro ao processar jogador {i}: {e}")
        erros.append(i)
    url1 = f"https://www.plusliga.pl/players/id/{i}.html"

    headers1 = {
      'authority': 'www.plusliga.pl',
      'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
      'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
      'cache-control': 'max-age=0',
      'cookie': 'contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; popshow=1; _ga_52DFT0WK4J=GS1.1.1706883187.4.1.1706883406.0.0.0; _ga=GA1.1.395578836.1706790043',
      'referer': 'https://www.plusliga.pl/players.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
      'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
      'sec-ch-ua-mobile': '?0',
      'sec-ch-ua-platform': '"Windows"',
      'sec-fetch-dest': 'document',
      'sec-fetch-mode': 'navigate',
      'sec-fetch-site': 'same-origin',
      'sec-fetch-user': '?1',
      'upgrade-insecure-requests': '1',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
    }

    response1 = requests.request("GET", url1, headers=headers1, data=payload)

    content_pg1 = response1.text
    source_pg1 = BeautifulSoup(content_pg1, 'html.parser')
    try:
   
      biop['player_name'] = source_pg1.find_all('h1', class_='playername')[0].text
      biop['player_age'] = source_pg1.find_all('div', class_='datainfo small')[0].text.split(':')[1].replace('.', '/')
      biop['player_height_cm'] = source_pg1.find_all('div', class_='datainfo text-center')[0].text.split(':')[1]
      biop['player_weight_kg'] = source_pg1.find_all('div', class_='datainfo text-center')[1].text.split(':')[1]
      biop['player_jump_height_cm'] = source_pg1.find_all('div', class_='datainfo text-center')[2].text.split(':')[1]
      biop['player_position'] = source_pg1.find_all('div', class_='datainfo small')[1].text.split(':')[1]
      biop['player_id'] = i
      
      
    except IndexError as e:
        print(f"Erro ao processar jogador {i}: {e}")
        erros.append(i)
    values.append(biop)
    print(values)

# %%
import requests

url = "https://www.plusliga.pl/statsPlayers/id/2125173.html"

payload = {}
headers = {
  'authority': 'www.plusliga.pl',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'pt-BR,pt;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': 'popshow=1; contentia=1a72e2a91af0a29ec7e36d3d7385d4db; cookie_manager=%7B%22consentType%22%3A%22allow-all%22%2C%22categoryList%22%3A%5B%22Niezb%C4%99dne%22%2C%22Reklamowe%22%2C%22Analityczne%22%5D%7D; _gid=GA1.2.1230343360.1706790043; popshow=1; _ga_52DFT0WK4J=GS1.1.1706921703.7.1.1706922140.0.0.0; _ga=GA1.2.395578836.1706790043; _gat=1; _gat_gtag_UA_3414984_6=1',
  'referer': 'https://www.plusliga.pl/statsPlayers/tournament_1/2023.html?memo=%7B%22players%22%3A%7B%22mainFilter%22%3A%22letter%22%2C%22subFilter%22%3A%22all%22%7D%7D',
  'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36'
}


response = requests.request("GET", url, headers=headers, data=payload)


content_pg = response.text
source_pg = BeautifulSoup(content_pg, 'html.parser')
tbody = source_pg.find_all('tbody')[1]
biop = {}
rows = tbody.find_all('tr')[-2]

biop['matches_played'] = [i.text for i in rows][1].split('(')[1].split(')')[0]
biop['sets_played'] = [i.text for i in rows][3]
biop['points'] = [i.text for i in rows][5]
biop['serves'] = [i.text for i in rows][7]
biop['aces'] = [i.text for i in rows][9]
biop['serves_mistakes'] = [i.text for i in rows][11]
biop['aces_per_set'] = [i.text for i in rows][13]
biop['reception'] = [i.text for i in rows][15]
biop['reception_mistakes'] = [i.text for i in rows][17]
biop['reception_bad'] = [i.text for i in rows][19]
biop['reception_perfect'] = [i.text for i in rows][21]
biop['reception_perfect%'] = [i.text for i in rows][23]
biop['attacks'] = [i.text for i in rows][25]
biop['attacks_mistakes'] = [i.text for i in rows][27]
biop['attacks_blocked'] = [i.text for i in rows][29]
biop['attacks_perfect'] = [i.text for i in rows][31]
biop['attacks_perfect%'] = [i.text for i in rows][33]
biop['blocks_points'] = [i.text for i in rows][35]
biop['blocks_points_perset'] = [i.text for i in rows][37]
biop
# Out:
# {'matches_played': '19',
#  'sets_played': '61',
#  'points': '115',
#  'serves': '126',
#  'aces': '11',
#  'serves_mistakes': '34',
#  'aces_per_set': '0,18',
#  'reception': '147',
#  'reception_mistakes': '13',
#  'reception_bad': '35',
#  'reception_perfect': '40',
#  'reception_perfect%': '27,21',
#  'attacks': '190',
#  'attacks_mistakes': '24',
#  'attacks_blocked': '18',
#  'attacks_perfect': '85',
#  'attacks_perfect%': '44,74',
#  'blocks_points': '19',
#  'blocks_points_perset': '0,31'}
